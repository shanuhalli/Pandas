# %% [markdown]
# ## Chapter 1 - Getting and Knowing your data

# %%
import pandas as pd

# %%
restaurent_sales = pd.read_table('D:\Data Science\Attachement\data.tsv.txt')
restaurent_sales
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
#pd.set_option('max_rows',None)

# %%
restaurent_sales.head(6)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 5  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98

# %%
restaurent_sales.tail(6)
# Out:
#       order_id  quantity            item_name  \
# 4616      1832         1  Chips and Guacamole
# 4617      1833         1        Steak Burrito
# 4618      1833         1        Steak Burrito
# 4619      1834         1   Chicken Salad Bowl
# 4620      1834         1   Chicken Salad Bowl
# 4621      1834         1   Chicken Salad Bowl
#
#                                      choice_description item_price
# 4616                                                NaN     $4.45
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75

# %% [markdown]
# ### 1.1 Perform Initial Analysis

# %%
restaurent_sales.shape #Attributes
# Out:
# (4622, 5)

# %%
restaurent_sales.dtypes #Attributes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
restaurent_sales.isna().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
restaurent_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
restaurent_sales.describe(include='all')
# Out:
#            order_id     quantity     item_name choice_description item_price
# count   4622.000000  4622.000000          4622               3376       4622
# unique          NaN          NaN            50               1043         78
# top             NaN          NaN  Chicken Bowl        [Diet Coke]     $8.75
# freq            NaN          NaN           726                134        730
# mean     927.254868     1.075725           NaN                NaN        NaN
# std      528.890796     0.410186           NaN                NaN        NaN
# min        1.000000     1.000000           NaN                NaN        NaN
# 25%      477.250000     1.000000           NaN                NaN        NaN
# 50%      926.000000     1.000000           NaN                NaN        NaN
# 75%     1393.000000     1.000000           NaN                NaN        NaN
# max     1834.000000    15.000000           NaN                NaN        NaN

# %% [markdown]
# ### 1.2 Find Out Total No of Orders Placed.

# %%
restaurent_sales['order_id'].nunique()
# Out:
# 1834

# %% [markdown]
# ### 1.3 Find out the items sold in this restaurent.

# %%
print(restaurent_sales['item_name'].unique())
# Out:
# ['Chips and Fresh Tomato Salsa' 'Izze' 'Nantucket Nectar'
#  'Chips and Tomatillo-Green Chili Salsa' 'Chicken Bowl' 'Side of Chips'
#  'Steak Burrito' 'Steak Soft Tacos' 'Chips and Guacamole'
#  'Chicken Crispy Tacos' 'Chicken Soft Tacos' 'Chicken Burrito'
#  'Canned Soda' 'Barbacoa Burrito' 'Carnitas Burrito' 'Carnitas Bowl'
#  'Bottled Water' 'Chips and Tomatillo Green Chili Salsa' 'Barbacoa Bowl'
#  'Chips' 'Chicken Salad Bowl' 'Steak Bowl' 'Barbacoa Soft Tacos'
#  'Veggie Burrito' 'Veggie Bowl' 'Steak Crispy Tacos'
#  'Chips and Tomatillo Red Chili Salsa' 'Barbacoa Crispy Tacos'
#  'Veggie Salad Bowl' 'Chips and Roasted Chili-Corn Salsa'
#  'Chips and Roasted Chili Corn Salsa' 'Carnitas Soft Tacos'
#  'Chicken Salad' 'Canned Soft Drink' 'Steak Salad Bowl'
#  '6 Pack Soft Drink' 'Chips and Tomatillo-Red Chili Salsa' 'Bowl'
#  'Burrito' 'Crispy Tacos' 'Carnitas Crispy Tacos' 'Steak Salad'
#  'Chips and Mild Fresh Tomato Salsa' 'Veggie Soft Tacos'
# ...

# %%
print(restaurent_sales['item_name'].nunique())
# Out:
# 50

# %%
restaurent_sales['item_name'].value_counts()
# Out:
# Chicken Bowl                             726
# Chicken Burrito                          553
# Chips and Guacamole                      479
# Steak Burrito                            368
# Canned Soft Drink                        301
# Steak Bowl                               211
# Chips                                    211
# Bottled Water                            162
# Chicken Soft Tacos                       115
# Chips and Fresh Tomato Salsa             110
# Chicken Salad Bowl                       110
# Canned Soda                              104
# Side of Chips                            101
# Veggie Burrito                            95
# Barbacoa Burrito                          91
# Veggie Bowl                               85
# Carnitas Bowl                             68
# Barbacoa Bowl                             66
# Carnitas Burrito                          59
# Steak Soft Tacos                          55
# 6 Pack Soft Drink                         54
# ...

# %% [markdown]
# ### 1.4 Display the top 5 ordered items.

# %%
restaurent_sales.groupby(by='item_name')['quantity'].sum().sort_values(ascending=False).head()
# Out:
# item_name
# Chicken Bowl           761
# Chicken Burrito        591
# Chips and Guacamole    506
# Steak Burrito          386
# Canned Soft Drink      351
# Name: quantity, dtype: int64

# %% [markdown]
# ### 1.5 Display 5 least ordered items.

# %%
restaurent_sales.groupby(by='item_name')['quantity'].sum().sort_values(ascending=False).tail()
# Out:
# item_name
# Salad                                2
# Crispy Tacos                         2
# Chips and Mild Fresh Tomato Salsa    1
# Carnitas Salad                       1
# Veggie Crispy Tacos                  1
# Name: quantity, dtype: int64

# %%
import warnings
warnings.filterwarnings(action = 'ignore')

# %%
restaurent_sales['item_price'] = restaurent_sales['item_price'].str.replace('$','')

# %%
restaurent_sales.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN      2.39
# 1                                       [Clementine]      3.39
# 2                                            [Apple]      3.39
# 3                                                NaN      2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...     16.98

# %%
restaurent_sales.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
restaurent_sales['item_price'] = restaurent_sales['item_price'].astype('float')

# %%
restaurent_sales.dtypes
# Out:
# order_id                int64
# quantity                int64
# item_name              object
# choice_description     object
# item_price            float64
# dtype: object

# %%
restaurent_sales['INR_Item_price'] = restaurent_sales['item_price'] * 79.28
restaurent_sales
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price  \
# 0                                                   NaN        2.39
# ...

# %%
restaurent_sales.shape
# Out:
# (4622, 6)

# %% [markdown]
# ### ========================================================================================

# %% [markdown]
# ## Chapter 2 - Filtering and Sorting

# %%
football_stats = pd.read_csv('D:\Data Science\Attachement\Euro_2012_stats_TEAM.csv')
football_stats
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# ### 2.1 Display first 5 observations of first 5 columns

# %%
football_stats.iloc[:5,:5] #Index Locator
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%

# %% [markdown]
# ### 2.2 Display first 5 observations of Team and Shooting Accuracy

# %%
football_stats.iloc[:5,[0,4]]
# Out:
#              Team Shooting Accuracy
# 0         Croatia             51.9%
# 1  Czech Republic             41.9%
# 2         Denmark             50.0%
# 3         England             50.0%
# 4          France             37.9%

# %%
football_stats.loc[:5,['Team','Shooting Accuracy']]
# Out:
#              Team Shooting Accuracy
# 0         Croatia             51.9%
# 1  Czech Republic             41.9%
# 2         Denmark             50.0%
# 3         England             50.0%
# 4          France             37.9%
# 5         Germany             47.8%

# %%
football_stats.iloc[[0,3,4],[0,4]]
# Out:
#       Team Shooting Accuracy
# 0  Croatia             51.9%
# 3  England             50.0%
# 4   France             37.9%

# %% [markdown]
# ### 2.3 Take all observations of Team, Shooting Accuracy, Red Cards and Yellow Cards.

# %%
filtered_data = football_stats[['Team','Shooting Accuracy','Red Cards','Yellow Cards']]
filtered_data
# Out:
#                    Team Shooting Accuracy  Red Cards  Yellow Cards
# 0               Croatia             51.9%          0             9
# 1        Czech Republic             41.9%          0             7
# 2               Denmark             50.0%          0             4
# 3               England             50.0%          0             5
# 4                France             37.9%          0             6
# 5               Germany             47.8%          0             4
# 6                Greece             30.7%          1             9
# 7                 Italy             43.0%          0            16
# 8           Netherlands             25.0%          0             5
# 9                Poland             39.4%          1             7
# 10             Portugal             34.3%          0            12
# 11  Republic of Ireland             36.8%          1             6
# 12               Russia             22.5%          0             6
# ...

# %% [markdown]
# ### 2.4 Display the team which got more Number of Yellow Cards

# %%
filtered_data.sort_values(by= 'Yellow Cards',ascending=False,inplace=True)

# %%
filtered_data
# Out:
#                    Team Shooting Accuracy  Red Cards  Yellow Cards
# 7                 Italy             43.0%          0            16
# 10             Portugal             34.3%          0            12
# 13                Spain             55.9%          0            11
# 0               Croatia             51.9%          0             9
# 6                Greece             30.7%          1             9
# 1        Czech Republic             41.9%          0             7
# 9                Poland             39.4%          1             7
# 14               Sweden             47.2%          0             7
# 4                France             37.9%          0             6
# 11  Republic of Ireland             36.8%          1             6
# 12               Russia             22.5%          0             6
# 3               England             50.0%          0             5
# 8           Netherlands             25.0%          0             5
# ...

# %% [markdown]
# ### 2.5 Display the teams that Got Yellow Cards more than 7 and Red Cards 1.

# %%
filtered_data[filtered_data['Yellow Cards']>7]
# Out:
#         Team Shooting Accuracy  Red Cards  Yellow Cards
# 7      Italy             43.0%          0            16
# 10  Portugal             34.3%          0            12
# 13     Spain             55.9%          0            11
# 0    Croatia             51.9%          0             9
# 6     Greece             30.7%          1             9

# %%
filtered_data[filtered_data['Red Cards'] == 1]
# Out:
#                    Team Shooting Accuracy  Red Cards  Yellow Cards
# 6                Greece             30.7%          1             9
# 9                Poland             39.4%          1             7
# 11  Republic of Ireland             36.8%          1             6

# %%
filtered_data[(filtered_data['Yellow Cards'] > 7) | (filtered_data['Red Cards'] == 1)]
# Out:
#                    Team Shooting Accuracy  Red Cards  Yellow Cards
# 7                 Italy             43.0%          0            16
# 10             Portugal             34.3%          0            12
# 13                Spain             55.9%          0            11
# 0               Croatia             51.9%          0             9
# 6                Greece             30.7%          1             9
# 9                Poland             39.4%          1             7
# 11  Republic of Ireland             36.8%          1             6

# %% [raw]
# filtered_data.query()

# %% [markdown]
# ### ========================================================================================

# %% [markdown]
# ## Chapter 3 - Delete

# %%
euro_2012_stats = pd.read_csv('D:\Data Science\Attachement\Euro_2012_stats_TEAM.csv')
euro_2012_stats
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
euro_2012_stats
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
euro_2012_stats.columns
# Out:
# Index(['Team', 'Goals', 'Shots on target', 'Shots off target',
#        'Shooting Accuracy', '% Goals-to-shots', 'Total shots (inc. Blocked)',
#        'Hit Woodwork', 'Penalty goals', 'Penalties not scored', 'Headed goals',
#        'Passes', 'Passes completed', 'Passing Accuracy', 'Touches', 'Crosses',
#        'Dribbles', 'Corners Taken', 'Tackles', 'Clearances', 'Interceptions',
#        'Clearances off line', 'Clean Sheets', 'Blocks', 'Goals conceded',
#        'Saves made', 'Saves-to-shots ratio', 'Fouls Won', 'Fouls Conceded',
#        'Offsides', 'Yellow Cards', 'Red Cards', 'Subs on', 'Subs off',
#        'Players Used'],
#       dtype='object')

# %%
from platform import python_version
python_version()
# Out:
# '3.9.12'

# %%
#Python version - 3.9.12
pd.set_option('display.max_column',None)

# %%
del euro_2012_stats['Shots on target']

# %%
euro_2012_stats
# Out:
#                    Team  Goals  Shots off target Shooting Accuracy  \
# 0               Croatia      4                12             51.9%
# 1        Czech Republic      4                18             41.9%
# 2               Denmark      4                10             50.0%
# 3               England      5                18             50.0%
# 4                France      3                24             37.9%
# 5               Germany     10                32             47.8%
# 6                Greece      5                18             30.7%
# 7                 Italy      6                45             43.0%
# 8           Netherlands      2                36             25.0%
# 9                Poland      2                23             39.4%
# 10             Portugal      6                42             34.3%
# 11  Republic of Ireland      1                12             36.8%
# 12               Russia      5                31             22.5%
# ...

# %%
euro_2012_stats.drop(labels=['Shots off target','Shooting Accuracy'],axis=1,inplace=True)

# %%
euro_2012_stats
# Out:
#                    Team  Goals % Goals-to-shots  Total shots (inc. Blocked)  \
# 0               Croatia      4            16.0%                          32
# 1        Czech Republic      4            12.9%                          39
# 2               Denmark      4            20.0%                          27
# 3               England      5            17.2%                          40
# 4                France      3             6.5%                          65
# 5               Germany     10            15.6%                          80
# 6                Greece      5            19.2%                          32
# 7                 Italy      6             7.5%                         110
# 8           Netherlands      2             4.1%                          60
# 9                Poland      2             5.2%                          48
# 10             Portugal      6             9.3%                          82
# ...

# %% [markdown]
# ### ========================================================================================

# %% [markdown]
# ## Chapter 4 - Creating Series and DataFrame
#
# Pandas has different DataStructures:
#
# * 1D - Series
# * 2D - DataFrame
# * 3D - Panel

# %%
vinil_marks = [99,95,98,97]
vinil_marks
# Out:
# [99, 95, 98, 97]

# %%
type(vinil_marks)
# Out:
# list

# %%
vinil_marks_pd = pd.Series(data=[99,95,98,97])
vinil_marks_pd
# Out:
# 0    99
# 1    95
# 2    98
# 3    97
# dtype: int64

# %%
type(vinil_marks_pd)
# Out:
# pandas.core.series.Series

# %%
learner_details = {'name':['Vinil','Vrushali'],
                   'age' :[26,25]}
learner_details
# Out:
# {'name': ['Vinil', 'Vrushali'], 'age': [26, 25]}

# %%
learner_details_pd = pd.DataFrame(data=learner_details)
learner_details_pd
# Out:
#        name  age
# 0     Vinil   26
# 1  Vrushali   25

# %%
type(learner_details_pd)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### ========================================================================================

# %% [markdown]
# ## Chapter 5 - Apply

# %%
student_details = pd.read_csv('D:\Data Science\Attachement\student-mat.csv')
student_details
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
student_details['Medu'] = student_details['Medu'] + 2

# %%
student_details
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     6     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     3     1   at_home     other
# 2       GP   F   15       U     LE3       T     3     1   at_home     other
# 3       GP   F   15       U     GT3       T     6     2    health  services
# 4       GP   F   16       U     GT3       T     5     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     4     2  services  services
# 391     MS   M   17       U     LE3       T     5     1  services  services
# 392     MS   M   21       R     GT3       T     3     1     other     other
# 393     MS   M   18       R     LE3       T     5     2  services     other
# 394     MS   M   19       U     LE3       T     3     1     other   at_home
#
# ...

# %%
student_details['Mjob'] = student_details['Mjob'].str.upper()

# %%
student_details
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     6     4   AT_HOME   teacher
# 1       GP   F   17       U     GT3       T     3     1   AT_HOME     other
# 2       GP   F   15       U     LE3       T     3     1   AT_HOME     other
# 3       GP   F   15       U     GT3       T     6     2    HEALTH  services
# 4       GP   F   16       U     GT3       T     5     3     OTHER     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     4     2  SERVICES  services
# 391     MS   M   17       U     LE3       T     5     1  SERVICES  services
# 392     MS   M   21       R     GT3       T     3     1     OTHER     other
# 393     MS   M   18       R     LE3       T     5     2  SERVICES     other
# 394     MS   M   19       U     LE3       T     3     1     OTHER   at_home
#
# ...

# %%
student_details['guardian'] = student_details['guardian'].apply(lambda x:x.capitalize())
student_details
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     6     4   AT_HOME   teacher
# 1       GP   F   17       U     GT3       T     3     1   AT_HOME     other
# 2       GP   F   15       U     LE3       T     3     1   AT_HOME     other
# 3       GP   F   15       U     GT3       T     6     2    HEALTH  services
# 4       GP   F   16       U     GT3       T     5     3     OTHER     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     4     2  SERVICES  services
# 391     MS   M   17       U     LE3       T     5     1  SERVICES  services
# 392     MS   M   21       R     GT3       T     3     1     OTHER     other
# 393     MS   M   18       R     LE3       T     5     2  SERVICES     other
# 394     MS   M   19       U     LE3       T     3     1     OTHER   at_home
#
# ...

# %% [markdown]
# ### Create a new column 'Eligibility_Criteria' where it returns 1 if Age>=18 else 0.

# %%
student_details['Eligibility_Criteria'] = student_details['age'].apply(lambda x:1 if x>=18 else 0)

# %%
student_details
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     6     4   AT_HOME   teacher
# 1       GP   F   17       U     GT3       T     3     1   AT_HOME     other
# 2       GP   F   15       U     LE3       T     3     1   AT_HOME     other
# 3       GP   F   15       U     GT3       T     6     2    HEALTH  services
# 4       GP   F   16       U     GT3       T     5     3     OTHER     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     4     2  SERVICES  services
# 391     MS   M   17       U     LE3       T     5     1  SERVICES  services
# 392     MS   M   21       R     GT3       T     3     1     OTHER     other
# 393     MS   M   18       R     LE3       T     5     2  SERVICES     other
# 394     MS   M   19       U     LE3       T     3     1     OTHER   at_home
#
# ...

# %%
del student_details['Eligibility_Criteria']

# %%
student_details
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     6     4   AT_HOME   teacher
# 1       GP   F   17       U     GT3       T     3     1   AT_HOME     other
# 2       GP   F   15       U     LE3       T     3     1   AT_HOME     other
# 3       GP   F   15       U     GT3       T     6     2    HEALTH  services
# 4       GP   F   16       U     GT3       T     5     3     OTHER     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     4     2  SERVICES  services
# 391     MS   M   17       U     LE3       T     5     1  SERVICES  services
# 392     MS   M   21       R     GT3       T     3     1     OTHER     other
# 393     MS   M   18       R     LE3       T     5     2  SERVICES     other
# 394     MS   M   19       U     LE3       T     3     1     OTHER   at_home
#
# ...

# %%
def get_age(x):
    if x>=18:
        return 1
    else:
        return 0

# %%
student_details['EC'] = student_details['age'].apply(get_age)
student_details
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     6     4   AT_HOME   teacher
# 1       GP   F   17       U     GT3       T     3     1   AT_HOME     other
# 2       GP   F   15       U     LE3       T     3     1   AT_HOME     other
# 3       GP   F   15       U     GT3       T     6     2    HEALTH  services
# 4       GP   F   16       U     GT3       T     5     3     OTHER     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     4     2  SERVICES  services
# 391     MS   M   17       U     LE3       T     5     1  SERVICES  services
# 392     MS   M   21       R     GT3       T     3     1     OTHER     other
# 393     MS   M   18       R     LE3       T     5     2  SERVICES     other
# 394     MS   M   19       U     LE3       T     3     1     OTHER   at_home
#
# ...

# %% [markdown]
# ### ========================================================================================

# %% [markdown]
# ## Chapter 6 - Concat | Merge | Append

# %%
sales_transaction_2017 = pd.read_csv('D:\Data Science\Attachement\Sales Transactions-2017.csv')
sales_transaction_2017
# Out:
#              Date    Voucher               Party            Product  \
# 0        1/4/2017      Sal:1    SOLANKI PLASTICS      DONA-VAI-9100
# 1        1/4/2017      Sal:1    SOLANKI PLASTICS    LITE FOAM(1200)
# 2        1/4/2017      Sal:2  SARNESWARA TRADERS  VISHNU CHOTA WINE
# 3        1/4/2017      Sal:2  SARNESWARA TRADERS    LITE FOAM(1200)
# 4        1/4/2017      Sal:2  SARNESWARA TRADERS      DONA-VAI-9100
# ...           ...        ...                 ...                ...
# 47285  31/03/2018  Sal:10042                 Vkp        10*10 SHEET
# 47286         NaN        NaN                 NaN                NaN
# 47287         NaN        NaN                 NaN                NaN
# 47288         NaN    Total                   NaN                NaN
# 47289         NaN    Total                   NaN                NaN
#
#                 Qty          Rate           Gross        Disc  Voucher Amount
# ...

# %%
sales_transaction_2018 = pd.read_csv('D:\Data Science\Attachement\Sales Transactions-2018.csv')
sales_transaction_2018
# Out:
#              Date   Voucher        Party            Product           Qty  \
# 0        1/4/2018   Sal:146         TP13  SILVER POUCH 9*12            50
# 1        1/4/2018   Sal:146         TP13             RUBBER             5
# 2        1/4/2018   Sal:146         TP13   DURGA 10*12 Blue      1,600.00
# 3        1/4/2018   Sal:146         TP13   DURGA 13*16 BLUE           400
# 4        1/4/2018   Sal:146         TP13    10*12 SARAS-NAT           600
# ...           ...       ...          ...                ...           ...
# 44735  31/03/2019  Sal:9610  HAMPI FOODS        SPOON SOOFY           200
# 44736         NaN       NaN          NaN                NaN           NaN
# 44737         NaN       NaN          NaN                NaN           NaN
# 44738         NaN   Total            NaN                NaN    666,056.00
# 44739         NaN   Total            NaN                NaN  7,097,803.00
#
#                 Rate           Gross        Disc  Voucher Amount
# ...

# %%
sales_transaction_2019 = pd.read_csv('D:\Data Science\Attachement\Sales Transactions-2019.csv')
sales_transaction_2019
# Out:
#              Date   Voucher            Party         Product           Qty  \
# 0        1/4/2019   Sal:687  BALAJI PLASTICS   DONA-VAI-9100             1
# 1        1/4/2019   Sal:687  BALAJI PLASTICS  SMART BOUL(48)             1
# 2        1/4/2019   Sal:688  BALAJI PLASTICS      Vishnu Ice           110
# 3                                       28/3                             0
# 4        1/4/2019   Sal:689  BALAJI PLASTICS     100LEAF -SP             3
# ...           ...       ...              ...             ...           ...
# 19171  10/10/2019  Sal:4935        K.SRIHARI  13*16 WHITE RK           400
# 19172         NaN       NaN              NaN             NaN           NaN
# 19173         NaN       NaN              NaN             NaN           NaN
# 19174         NaN   Total                NaN             NaN     99,284.90
# 19175         NaN   Total                NaN             NaN  2,710,193.00
#
#                Rate          Gross        Disc Voucher Amount
# ...

# %%
sales_complete_data = pd.concat([sales_transaction_2017,sales_transaction_2018,sales_transaction_2019])
sales_complete_data
# Out:
#              Date   Voucher               Party            Product  \
# 0        1/4/2017     Sal:1    SOLANKI PLASTICS      DONA-VAI-9100
# 1        1/4/2017     Sal:1    SOLANKI PLASTICS    LITE FOAM(1200)
# 2        1/4/2017     Sal:2  SARNESWARA TRADERS  VISHNU CHOTA WINE
# 3        1/4/2017     Sal:2  SARNESWARA TRADERS    LITE FOAM(1200)
# 4        1/4/2017     Sal:2  SARNESWARA TRADERS      DONA-VAI-9100
# ...           ...       ...                 ...                ...
# 19171  10/10/2019  Sal:4935           K.SRIHARI     13*16 WHITE RK
# 19172         NaN       NaN                 NaN                NaN
# 19173         NaN       NaN                 NaN                NaN
# 19174         NaN   Total                   NaN                NaN
# 19175         NaN   Total                   NaN                NaN
#
#                 Qty          Rate          Gross        Disc Voucher Amount
# 0                 2      1,690.00       3,380.00         NaN      13,100.00
# ...

# %%
sales_transaction_2017.append([sales_transaction_2018,sales_transaction_2019])
# Out:
#              Date   Voucher               Party            Product  \
# 0        1/4/2017     Sal:1    SOLANKI PLASTICS      DONA-VAI-9100
# 1        1/4/2017     Sal:1    SOLANKI PLASTICS    LITE FOAM(1200)
# 2        1/4/2017     Sal:2  SARNESWARA TRADERS  VISHNU CHOTA WINE
# 3        1/4/2017     Sal:2  SARNESWARA TRADERS    LITE FOAM(1200)
# 4        1/4/2017     Sal:2  SARNESWARA TRADERS      DONA-VAI-9100
# ...           ...       ...                 ...                ...
# 19171  10/10/2019  Sal:4935           K.SRIHARI     13*16 WHITE RK
# 19172         NaN       NaN                 NaN                NaN
# 19173         NaN       NaN                 NaN                NaN
# 19174         NaN   Total                   NaN                NaN
# 19175         NaN   Total                   NaN                NaN
#
#                 Qty          Rate          Gross        Disc Voucher Amount
# 0                 2      1,690.00       3,380.00         NaN      13,100.00
# ...

# %%
sales_complete_data.shape
# Out:
# (111206, 9)

# %%
sales_complete_data.to_csv('Sales_CLEANED.csv')

# %%
sales_complete_data.head(15)
# Out:
#         Date   Voucher                Party             Product  Qty  \
# 0   1/4/2017     Sal:1     SOLANKI PLASTICS       DONA-VAI-9100    2
# 1   1/4/2017     Sal:1     SOLANKI PLASTICS     LITE FOAM(1200)    6
# 2   1/4/2017     Sal:2   SARNESWARA TRADERS   VISHNU CHOTA WINE  500
# 3   1/4/2017     Sal:2   SARNESWARA TRADERS     LITE FOAM(1200)    6
# 4   1/4/2017     Sal:2   SARNESWARA TRADERS       DONA-VAI-9100    5
# 5   1/4/2017     Sal:2   SARNESWARA TRADERS  CLASSIC ENJOY(750)    1
# 6   1/4/2017   Sal:898                 Lock        Vishnu 250ml  100
# 7   1/4/2017   Sal:898                 Lock     BLACK DOG-350ML  100
# 8                       khader vali late en
# 9                                       try
# 10  1/4/2017  Sal:2497  VAMSI KRISHNA FANCY         Loose Items    1
# 11       NaN       NaN               #NAME?                 NaN  NaN
# 12                              DUMMY ENTRY
# 13  1/4/2017  Sal:9263  VAMSI KRISHNA FANCY         Loose Items    1
# ...

# %%
sales_cleaned_data = pd.read_csv('D:\Data Science\Attachement\Sales-Transactions-Edited.csv')
sales_cleaned_data
# Out:
#             Date  Voucher               Party              Product  Qty  \
# 0       1/4/2017        1    SOLANKI PLASTICS        DONA-VAI-9100    2
# 1       1/4/2017        1    SOLANKI PLASTICS      LITE FOAM(1200)    6
# 2       1/4/2017        2  SARNESWARA TRADERS    VISHNU CHOTA WINE  500
# 3       1/4/2017        2  SARNESWARA TRADERS      LITE FOAM(1200)    6
# 4       1/4/2017        2  SARNESWARA TRADERS        DONA-VAI-9100    5
# ...          ...      ...                 ...                  ...  ...
# 95557  12/9/2019     4265                TP13        SPOON MED M.W   20
# 95558  12/9/2019     4266           K.SRIHARI       SMART BOUL(48)    1
# 95559  12/9/2019     4267                 SMS  SMARTBOUL GLA(4000)    1
# 95560  12/9/2019     4268           ANILFANCY         RR WINEGLASS  100
# 95561  12/9/2019     4268           ANILFANCY       RR WATER GLASS  100
#
#          Rate
# 0      1690.0
# 1      1620.0
# 2        23.0
# 3      1620.0
# 4      1690.0
# ...

# %%
sales_cleaned_data.head(15)
# Out:
#         Date  Voucher                Party              Product   Qty     Rate
# 0   1/4/2017        1     SOLANKI PLASTICS        DONA-VAI-9100     2  1690.00
# 1   1/4/2017        1     SOLANKI PLASTICS      LITE FOAM(1200)     6  1620.00
# 2   1/4/2017        2   SARNESWARA TRADERS    VISHNU CHOTA WINE   500    23.00
# 3   1/4/2017        2   SARNESWARA TRADERS      LITE FOAM(1200)     6  1620.00
# 4   1/4/2017        2   SARNESWARA TRADERS        DONA-VAI-9100     5  1690.00
# 5   1/4/2017        2   SARNESWARA TRADERS   CLASSIC ENJOY(750)     1  1320.00
# 6   1/4/2017      898                 LOCK         VISHNU 250ML   100    30.00
# 7   1/4/2017      898                 LOCK      BLACK DOG-350ML   100    26.00
# 8   1/4/2017     2497  VAMSI KRISHNA FANCY          LOOSE ITEMS     1   800.00
# 9   1/4/2017     9263  VAMSI KRISHNA FANCY          LOOSE ITEMS     1   280.00
# 10  1/4/2017     9545                  VKP          LOOSE ITEMS     1   695.00
# ...

# %%
sales_cleaned_data.dtypes
# Out:
# Date        object
# Voucher      int64
# Party       object
# Product     object
# Qty          int64
# Rate       float64
# dtype: object

# %%
sales_complete_data.dtypes
# Out:
# Date              object
# Voucher           object
# Party             object
# Product           object
# Qty               object
# Rate              object
# Gross             object
# Disc              object
# Voucher Amount    object
# dtype: object

# %%
sales_cleaned_data.isna().sum()
# Out:
# Date       0
# Voucher    0
# Party      0
# Product    0
# Qty        0
# Rate       1
# dtype: int64

# %%
sales_complete_data.isna().sum()
# Out:
# Date               12591
# Voucher            12557
# Party                 40
# Product            12591
# Qty                12557
# Rate               12558
# Gross              12558
# Disc              105609
# Voucher Amount     83646
# dtype: int64

# %% [markdown]
# ### ========================================================================================

# %% [markdown]
# ## Chapter 7 - Grouping Vs Pivot Table Vs CrossTab

# %%
insurance_details = pd.read_csv('D:\Data Science\Attachement\insurance.csv')
insurance_details
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
insurance_details['region'].unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %% [markdown]
# ### 7.1 Display the average insurance charges based on regions.

# %%
insurance_details.groupby(by='region')['charges'].mean().round().sort_values(ascending = False)
# Out:
# region
# southeast    14735.0
# northeast    13406.0
# northwest    12418.0
# southwest    12347.0
# Name: charges, dtype: float64

# %% [markdown]
# ### 7.2 Display the average insurance charges based on regions and gender.

# %%
insurance_details.groupby(by=['region','sex'])['charges'].mean().round().sort_values(ascending = False)
# Out:
# region     sex
# southeast  male      15880.0
# northeast  male      13854.0
# southeast  female    13500.0
# southwest  male      13413.0
# northeast  female    12953.0
# northwest  female    12480.0
#            male      12354.0
# southwest  female    11274.0
# Name: charges, dtype: float64

# %%
pd.pivot_table(data = insurance_details , values='charges', index='region', columns='sex',aggfunc='mean').round()
# Out:
# sex         female     male
# region
# northeast  12953.0  13854.0
# northwest  12480.0  12354.0
# southeast  13500.0  15880.0
# southwest  11274.0  13413.0

# %%
pd.crosstab(index = insurance_details['region'],columns = insurance_details['sex'],margins=True)
#By default,computes a frequency table of the factors
# Out:
# sex        female  male   All
# region
# northeast     161   163   324
# northwest     164   161   325
# southeast     175   189   364
# southwest     162   163   325
# All           662   676  1338

# %% [markdown]
# # THE END!!!
